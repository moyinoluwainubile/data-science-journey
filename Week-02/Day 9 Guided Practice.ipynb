# %%
age=25
print(age)
print(id(age))
# Out:
# 25
# 140732206606200

# %%
years_lived=age
print(years_lived)
print(id(years_lived))
# Out:
# 25
# 140732206606200

# %%
age=30
print(age)
print(years_lived)
print(id(age))
# Out:
# 30
# 25
# 140732206606360

# %%
x=5
y=x
x=100
print(y)
# Out:
# 5

# %%
list1=[1, 2, 3]
list2=list1
list1.append(4)
print(list2)
# Out:
# [1, 2, 3, 4]
